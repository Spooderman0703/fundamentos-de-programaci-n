# %% [markdown]
# ## **Ejercicios extras evaluables**.

# %% [markdown]
# **Extra 1: Suma de todos los elementos de una matriz**
#
# Crea una función suma_matriz(matriz) que regrese valor (con return) la suma de todos los elementos de una lista de listas, usando ciclos for anidados. Define además una función imprimir_matriz(matriz) que no regrese valor y muestre la matriz sin corchetes ni comas. Aplica ambas funciones a la matriz [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
def imprimir_matriz(matriz):
    for fila in matriz:
        for elemento in fila:
            print(elemento, end=" ")
        print()

def suma_matriz(matriz):
    suma_total = 0
    for fila in matriz:
        for elemento in fila:
            suma_total += elemento
    return suma_total




matriz = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
imprimir_matriz(matriz)
print (f"La suma de todos los valores de la matriz es: {suma_matriz(matriz)}")
# Out:
# 1 2 3
# 4 5 6
# 7 8 9
# La suma de todos los valores de la matriz es: 45

# %% [markdown]
# **Extra 2: Matriz con suma por fila**
#
#
# Crea una función suma_fila(fila) que regrese valor (con return) la suma de los elementos de una lista, y una función mostrar_tabla(matriz) que no regrese valor e imprima la matriz sin corchetes ni comas. Dada la matriz [[3, 1, 4], [1, 5, 9], [2, 6, 5]], imprime la matriz y la suma de cada fila.

# %%
def mostrar_tabla(matriz):
    for fila in matriz:
        for elemento in fila:
            print(elemento, end=" ")
        print()

def suma_fila(fila):
    suma_total = 0
    for e in fila:
        suma_total += e
    return suma_total

matriz = [[3, 1, 4], [1, 5, 9], [2, 6, 5]]

mostrar_tabla(matriz)

print(f"Suma de la fila 0: {suma_fila(matriz[0])}")
print(f"Suma de la fila 1: {suma_fila(matriz[1])}")
print(f"Suma de la fila 2: {suma_fila(matriz[2])}")
# Out:
# 3 1 4
# 1 5 9
# 2 6 5
# Suma de la fila 0: 8
# Suma de la fila 1: 15
# Suma de la fila 2: 13

# %% [markdown]
# **Extra 3: Producto de una columna sin usar el operador '*'**
#
# Crea la matriz [[1, 2, 3], [4, 5, 6], [7, 8, 9], [2, 4, 6]] (4 filas y 3 columnas). Define una función multiplicar_columna(matriz, columna) que regrese valor (con return) el producto de los elementos de una columna dada. Restricción: dentro de la función está prohibido usar el operador *; el producto debe calcularse con sumas repetidas usando un ciclo. Pide al usuario el número de columna (0, 1 o 2) y muestra el resultado.

# %%
def multiplicar_columna(matriz, columna):
    if columna == 0:
        suma_total= 0
        for i in columna:
            for e in range(i):
                suma_total+=e
        return suma_total

matriz = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9],
    [2, 4, 6]
]
columna = 0
num_columna = int(input("¿Qué número de columna deseas obtener su resultado (0, 1 o 2): ?"))

if num_columna == 0:
    num_columna = columna
    print(f"El producto de la columna {num_columna} es: {multiplicar_columna(matriz, columna)}")
elif num_columna == 1:
    print()
elif num_columna == 2:
    print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 20
#      16 num_columna = int(input("¿Qué número de columna deseas obtener su resultado (0, 1 o 2): ?"))
#      17
#      18 if num_columna == 0:
#      19     num_columna = columna
# ---> 20     print(f"El producto de la columna {num_columna} es: {multiplicar_columna(matriz, columna)}")
#      21 elif num_columna == 1:
#      22     print()
#      23 elif num_columna == 2:
#
# Cell In[22], line 4, in multiplicar_columna(matriz, columna)
#       1 def multiplicar_columna(matriz, columna):
#       2     if columna == 0:
#       3         suma_total= 0
# ----> 4         for i in columna:
#       5             for e in range(i):
#       6                 suma_total+=e
#       7         return suma_total
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# **Extra 4: Tabla de Pitágoras de tamaño variable**
#
# Crea una función generar_tabla(tamano) que regrese valor (con return) una lista de listas de tamano x tamano con los productos de la tabla de Pitágoras (renglones y columnas del 1 al tamano). Dentro de la función de generación está prohibido usar el operador *; usa sumas repetidas con ciclos. Define una función imprimir_tabla(tabla) que no regrese valor e imprima la tabla sin corchetes ni comas, con los números tabulados (\t). Pide al usuario un tamaño entre 2 y 5; si ingresa un valor fuera del rango, muestra un mensaje de error. Al final pide un renglón y una columna y muestra el producto consultando la matriz, sin usar *
